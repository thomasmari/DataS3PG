# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import missingno as msno

# %%
data_titanic = "./Datasets/data_titanic.csv"
data_energy_nat = "./Datasets/df_nat.csv"

# %% [markdown]
# # Titanic Dataset

# %% [markdown]
# ## Import data

# %%
df_titanic = pd.read_csv(data_titanic)
df_energy = pd.read_csv(data_energy_nat)

# %% [markdown]
# ## Visualize Data

# %% [markdown]
# ### <font color='purple'> Quelle est la répartition des passagers par classe ? </font>
# -> Single categorical variable (une seule variable qualitative)
#
# Barplot

# %%
# Out:
# [<matplotlib.axis.XTick at 0x763e04457510>,
#  <matplotlib.axis.XTick at 0x763e04481e50>,
#  <matplotlib.axis.XTick at 0x763e046ad9d0>,
#  <matplotlib.axis.XTick at 0x763e044d2550>,
#  <matplotlib.axis.XTick at 0x763e044d4850>,
#  <matplotlib.axis.XTick at 0x763e04573790>,
#  <matplotlib.axis.XTick at 0x763e044d79d0>,
#  <matplotlib.axis.XTick at 0x763e044d9dd0>,
#  <matplotlib.axis.XTick at 0x763e044dc390>,
#  <matplotlib.axis.XTick at 0x763e044de590>,
#  <matplotlib.axis.XTick at 0x763e044dadd0>,
#  <matplotlib.axis.XTick at 0x763e04537c50>,
#  <matplotlib.axis.XTick at 0x763e044738d0>,
#  <matplotlib.axis.XTick at 0x763e046a0290>,
#  <matplotlib.axis.XTick at 0x763e043028d0>,
#  <matplotlib.axis.XTick at 0x763e0430cc50>,
#  <matplotlib.axis.XTick at 0x763e0430ef90>,
#  <matplotlib.axis.XTick at 0x763e0430f890>,
#  <matplotlib.axis.XTick at 0x763e04315c10>,
#  <matplotlib.axis.XTick at 0x763e04317f90>]

# %% [markdown]
# ### <font color='purple'> Quelle est la répartition des passagers par sexe ? </font>
# -> type of variable(s)?
#
# pie plot

# %% [markdown]
# ### <font color='purple'>Distribution des passagers selon âge et sexe </font>
# -> type of variable(s)?
#
# Stacked histogramme

# %%
tmp = df_titanic[['Age', 'Sex']]
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(
    tmp,
    x="Age", hue="Sex",
    multiple="stack",
    palette="light:m_r",
    edgecolor=".3",
    linewidth=.5,
    binwidth=5
)
ax.xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())
ax.set_xticks([i for i in range(0, 100, 5)])
# Out:
# [<matplotlib.axis.XTick at 0x763dfe631050>,
#  <matplotlib.axis.XTick at 0x763dfe661b10>,
#  <matplotlib.axis.XTick at 0x763dfe4b1450>,
#  <matplotlib.axis.XTick at 0x763dfe4b3990>,
#  <matplotlib.axis.XTick at 0x763dfe4b5e90>,
#  <matplotlib.axis.XTick at 0x763dfe4bc250>,
#  <matplotlib.axis.XTick at 0x763dfe4b7750>,
#  <matplotlib.axis.XTick at 0x763dfe6208d0>,
#  <matplotlib.axis.XTick at 0x763dfe4c9350>,
#  <matplotlib.axis.XTick at 0x763dfe4cb790>,
#  <matplotlib.axis.XTick at 0x763dfe4cdb50>,
#  <matplotlib.axis.XTick at 0x763dfe4bcc50>,
#  <matplotlib.axis.XTick at 0x763dfe470a50>,
#  <matplotlib.axis.XTick at 0x763dfe662e10>,
#  <matplotlib.axis.XTick at 0x763dfe4f8bd0>,
#  <matplotlib.axis.XTick at 0x763dfe5d9010>,
#  <matplotlib.axis.XTick at 0x763dfe4fb810>,
#  <matplotlib.axis.XTick at 0x763dfe4fdb10>,
#  <matplotlib.axis.XTick at 0x763dfe4fff90>,
#  <matplotlib.axis.XTick at 0x763dfe502510>]

# %% [markdown]
# ### <font color='purple'>Quel est le taux de survie selon le sexe ? l’âge ? la classe ? </font>
# -> type of variable(s)?
#
# survie vs Sexe : lolipop (Moi)
#
# survie vs age : line plot
#
# survie vs classe : Barplot

# %%
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(7, 5))
tmp = df_titanic[['Survived','Sex']].groupby('Sex').mean()
tmp.plot.bar(ax=ax)
ax.set_ylabel("survival rate")
labels = ['One', 'Two', 'Three']
ax.set_xticks([0, 1])
ax.set_xticklabels(["male","female"], rotation=0)
# Out:
# [Text(0, 0, 'male'), Text(1, 0, 'female')]

# %%
tmp.groupe
# Out:
#      Survived   Age  Age_rounded_by_5
# 0           0  22.0                20
# 1           1  38.0                35
# 2           1  26.0                25
# 3           1  35.0                35
# 4           0  35.0                35
# ..        ...   ...               ...
# 885         0  39.0                35
# 886         0  27.0                25
# 887         1  19.0                15
# 889         1  26.0                25
# 890         0  32.0                30
#
# [714 rows x 3 columns]

# %%
tmp.dtypes
# Out:
# Survived              int64
# Age                 float64
# Age_rounded_by_5      int64
# dtype: object

# %%
set((tmp['Age_rounded_by_5'].values))
# Out:
# {np.int64(0),
#  np.int64(5),
#  np.int64(10),
#  np.int64(15),
#  np.int64(20),
#  np.int64(25),
#  np.int64(30),
#  np.int64(35),
#  np.int64(40),
#  np.int64(45),
#  np.int64(50),
#  np.int64(55),
#  np.int64(60),
#  np.int64(65),
#  np.int64(70),
#  np.int64(80)}

# %%
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(7, 5))
tmp = df_titanic[['Survived','Age']].dropna()
tmp[['Age_rounded_by_5']] = tmp[['Age']].map(lambda x : (int(x)// 5)*5)
tmp[['Survived','Age_rounded_by_5']].groupby('Age_rounded_by_5').mean().plot(ax=ax)
ax.set_xlabel("Age rounded by 5")
ax.set_ylabel("Survival rate")
ax.set_xticks(list(set((tmp['Age_rounded_by_5'].values))))
ax.grid()
# ax.set_xticklabels(["male","female"], rotation=0)

# %% [markdown]
# ### <font color='purple'> Y a-t-il un lien entre prix payé pour le billet et l’âge des passagers ? </font>
# -> type of variable(s)?
#
# Scatter plot

# %% [markdown]
# # Energy Dataset

# %% [markdown]
# ## Import data

# %% [markdown]
# ## Visualize Data

# %% [markdown]
# ### <font color='purple'> Quels sont les types de variables ? Comment sont distribuées les différentes variables présentées dans ce jeu de données ? </font>

# %%
df_energy
# Out:
#                    DateTime  Consommation  Fioul  Charbon     Gaz  Nucléaire  \
# 0       2012-01-01 00:00:00       58315.0  492.0     25.0  3816.0    52697.0
# 1       2012-01-01 00:15:00           NaN    NaN      NaN     NaN        NaN
# 2       2012-01-01 00:30:00       58315.0  492.0     25.0  3816.0    52697.0
# 3       2012-01-01 00:45:00           NaN    NaN      NaN     NaN        NaN
# 4       2012-01-01 01:00:00       56231.0  492.0     25.0  3834.0    51747.0
# ...                     ...           ...    ...      ...     ...        ...
# 245467  2018-12-31 22:45:00           NaN    NaN      NaN     NaN        NaN
# 245468  2018-12-31 23:00:00       63977.0  146.0     11.0  3910.0    55589.0
# 245469  2018-12-31 23:15:00           NaN    NaN      NaN     NaN        NaN
# 245470  2018-12-31 23:30:00       63803.0  146.0     12.0  3452.0    55404.0
# 245471  2018-12-31 23:45:00           NaN    NaN      NaN     NaN        NaN
#
#         Eolien  Solaire  Hydraulique  Pompage  Bioénergies  Ech. physiques
# 0       3588.0      0.0       7922.0  -1139.0        719.0         -9806.0
# 1          NaN      NaN          NaN      NaN          NaN             NaN
# 2       3588.0      0.0       7922.0  -1139.0        719.0         -9806.0
# 3          NaN      NaN          NaN      NaN          NaN             NaN
# 4       3536.0      0.0       7598.0  -1730.0        721.0         -9993.0
# ...        ...      ...          ...      ...          ...             ...
# 245467     NaN      NaN          NaN      NaN          NaN             NaN
# 245468  1537.0     -2.0       5148.0  -1364.0       1172.0         -2171.0
# 245469     NaN      NaN          NaN      NaN          NaN             NaN
# 245470  1543.0     -2.0       4688.0  -1474.0       1166.0         -1133.0
# 245471     NaN      NaN          NaN      NaN          NaN             NaN
#
# [245472 rows x 12 columns]

# %% [markdown]
# ### <font color='purple'> Quelle est l'évolution de la consommation ? </font>
#
# Line plot

# %%
fig = plt.figure(figsize=(16,6))
ax = plt.subplot(1,1,1)
df_energy.boxplot(ax=ax)
ax.set_yscale('symlog')
ax.set_ylabel('Energie')
# Out:
# Text(0, 0.5, 'Energie')

# %% [markdown]
# ### <font color='purple'> Quand a-t-on a un excédant / un déficit de production ? </font>
#
# Area plot fill between Production et consommation

# %% [markdown]
# ### <font color='purple'> Y a-t-il une corrélation entre les différents types de production ? </font>
#
# Heatmap de la matrice de correlation

# %%
quanta_col = ['Consommation', 'Fioul', 'Charbon', 'Gaz', 'Nucléaire',
       'Eolien', 'Solaire', 'Hydraulique', 'Pompage', 'Bioénergies',
       'Ech. physiques']
df_corr = df_energy[quanta_col].corr()

# %%
df_corr
