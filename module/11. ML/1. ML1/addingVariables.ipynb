# %% [markdown]
# # Etape 3 Ajoutez de nouvelles variables à votre modèle pour améliorer les performances

# %%
#Importing data
import pandas as pd
data = pd.read_pickle("data/trees_clean.p")
data.head(5)
# Out:
#    SOUS_CATEGORIE CODE_PARENT  ADR_SECTEUR GENRE_BOTA ESPECE  \
# 13         ESP151    ESP36926            1        NaN    NaN
# 14         ESP151    ESP36926            1        NaN    NaN
# 15         ESP151    ESP36926            1        NaN    NaN
# 16         ESP151    ESP36926            1        NaN    NaN
# 17         ESP151    ESP36926            1   Platanus    NaN
#
#    STADEDEDEVELOPPEMENT  ANNEEDEPLANTATION              COLLECTIVITE  \
# 13                  NaN             2017.0  Grenoble Alpes Métropole
# 14                  NaN             2017.0  Grenoble Alpes Métropole
# 15                  NaN             2017.0  Grenoble Alpes Métropole
# 16                  NaN             2017.0  Grenoble Alpes Métropole
# 17                  NaN             2017.0  Grenoble Alpes Métropole
#
#     LONGITUDE   LATITUDE
# 13   5.709930  45.201111
# 14   5.709895  45.201185
# 15   5.709864  45.201254
# 16   5.709828  45.201321
# 17   5.709681  45.201682

# %%
data['GENRE_BOTA_ESPECE'] = data['GENRE_BOTA']+' '+ data['ESPECE']

# %%
data
# Out:
#       SOUS_CATEGORIE CODE_PARENT  ADR_SECTEUR GENRE_BOTA    ESPECE  \
# 13            ESP151    ESP36926            1        NaN       NaN
# 14            ESP151    ESP36926            1        NaN       NaN
# 15            ESP151    ESP36926            1        NaN       NaN
# 16            ESP151    ESP36926            1        NaN       NaN
# 17            ESP151    ESP36926            1   Platanus       NaN
# ...              ...         ...          ...        ...       ...
# 31238         ESP151     ESP1277            1   Fraxinus  oxycarpa
# 31239         ESP151     ESP1277            1   Fraxinus  oxycarpa
# 31240         ESP151     ESP1277            1   Fraxinus  oxycarpa
# 31241         ESP151     ESP1277            1   Fraxinus  oxycarpa
# 31242         ESP151     ESP1277            1   Fraxinus  oxycarpa
#
#       STADEDEDEVELOPPEMENT  ANNEEDEPLANTATION              COLLECTIVITE  \
# 13                     NaN             2017.0  Grenoble Alpes Métropole
# ...
