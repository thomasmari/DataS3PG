# %% [markdown]
# # Mémo Git
#
# ## Troubleshooting
# - install
# ```bash
# (base) tmari@PYTHON-02:~/Documents/module/6.Git$2,09:36$git sudo apt install git
# ```
#
# - add git to PATH:
#
# ![image](memo_img/gitToPath.png)
#
# - Version:
# ```bash
# foo@bar:~$ git --version
# ```

# %% [markdown]
# ## Configuration
# - Set up your mail
# ```bash
# (base) tmari@PYTHON-02:~/Documents/module/6.Git$2,09:36$ git config --global user.email "you@example.com"
# ```
# - Set up your name
# ```bash
# (base) tmari@PYTHON-02:~/Documents/module/6.Git$2,09:36$ git config --global user.name "Thomas Mari"
# ```
# - Access info
# ```bash
# (base) tmari@PYTHON-02:~/Documents/module/6.Git$2,09:56$git config --list
# user.name=Thomas Mari
# user.email=thomas.mari@le-campus-numerique.fr
# ```
# - create a git
# ```bash
# (base) tmari@PYTHON-02:~/Documents/module/6.Git$4,10:20$git init
# ...
# Dépôt Git vide initialisé dans /home/thomas.mari@Digital-Grenoble.local/Documents/module/6.Git/.git/
# ```
# - check status of files in the git repo
# ```bash
# (base) tmari@PYTHON-02:~/Documents/module/6.Git$10,10:23$git status
# Sur la branche master
#
# Aucun commit
#
# Modifications qui seront validées :
#   (utilisez "git rm --cached <fichier>..." pour désindexer)
#         nouveau fichier : Support/KitApprenant_Git.pdf
#         nouveau fichier : memo_git.ipynb
#         nouveau fichier : memo_img/gitToPath.png
# ```

# %% [markdown]
# ## update local and online repo
# - pull online changes to local
# ```bash
# (base) tmari@PYTHON-02:~/Documents/module/6.Git$51,12:16$git pull
# ```
# - push local change to repo
# ```bash
# (base) tmari@PYTHON-02:~/Documents/module/6.Git$52,12:39$git push
# ```

# %% [markdown]
# ## Code Versionning
#
#
# - add files
# ```bash
# (base) tmari@PYTHON-02:~/Documents/module/6.Git$7,10:22$git add memo_git.ipynb
# ...
# ```
# - Commit staged changes with a message
# ```bash
# git commit -m "message"
# ```
# - Commit all tracked changes (skip staging)
# ```bash
# git commit -a -m "message"
# ```
# - See commit history
# ```bash
# git log -oneline
# git log --stat
# ```
#
# - make a commit
# ```bash
# (base) tmari@PYTHON-02:~/Documents/module/6.Git$13,10:28$git commit -am "Init git and adding some files"
# [master (commit racine) e93ff9e] Init git and adding some files
#  3 files changed, 72 insertions(+)
#  create mode 100644 Support/KitApprenant_Git.pdf
#  create mode 100644 memo_git.ipynb
#  create mode 100644 memo_img/gitToPath.png
# ```
# - browse logs of commits
# ```bash
# (base) tmari@PYTHON-02:~/Documents/module/6.Git$14,10:29$git log
# commit e93ff9ecd40bc0190a994abe626628c9f8a57a5e (HEAD -> master)
# Author: Thomas Mari <thomas.mari@le-campus-numerique.fr>
# Date:   Tue May 20 10:29:22 2025 +0200
#
#     Init git and adding some files
# ```
# - revert uncommited changes
# ```bash
# (base) tmari@PYTHON-02:~/Documents/module/6.Git$36,11:12$git restore temp.txt
# ```
# - unstage all files you might have staged with git add:
#
# ```bash
# git reset
# ```
# - revert all local uncommitted changes (should be executed in repo root):
# ```bash
# git checkout .
# ```
# - revert uncommitted changes only to particular file or directory:
# ```bash
# git checkout [some_dir|file.txt]
# ```
# - revert all uncommitted changes (longer to type, but works from any subdirectory):
# ```bash
# git reset --hard HEAD
# ```
# - remove all local untracked files, so only git tracked files remain:        WARNING: -x will also remove all ignored files, including ones specified by .gitignore! You may want to use -n for preview of files to be deleted.
# ```bash
# git clean -fdx
# ```
# - reset the world: equivalent to fresh git clone from original source (but it does not re-download anything, so is much faster):
# ```bash
# git reset
# git checkout .
# git clean -fdx
# ```
# - Stash your changes
# ```bash
# git stash
# ```
# - Stash with a message
# ```bash
# git stash push -m "message"
# ```
# - List all stashes
# ```bash
# git stash list
# ```
# - Create a branch from a stash
# ```bash
# git stash branch <branchname>
# ```
